# %% [markdown]
# # Appendix 16 - Timestamped Text of the 2018 State of the Union Address

# %%
import pandas as pd
from datetime import datetime
from datetime import timedelta

# Create empty dictionary with three keys
speechdict = {"time": [], "content": [], "linebreak": []}

# The full transcript and video/audio (with subtitles) of the speech was published by hundreds of online news outlets
# We thus obtained a timestamped version of the speech text
# Here we loop through the text file of the speech and append context into dictionary
with open("speech.txt") as speech:
    for line in speech:
        speechdict['time'].append(speech.readline())
        speechdict['content'].append(speech.readline())
        speechdict['linebreak'].append(speech.readline())

# %%
speechdict
# Out:
# {'content': ['Mr.. Speaker\n',
#   'Mr.. Vice president members\n',
#   'of Congress\n',
#   'the first lady of the United States and my fellow Americans\n',
#   'Less than one year has passed since I first stood at this podium\n',
#   'in this majestic chamber\n',
#   'To speak on behalf of the American people and to address their concerns their hopes and their dreams\n',
#   'That night our new administration had already taken very swift action a\n',
#   'New tide of optimism was already sweeping across our land\n',
#   'Each day since we have gone forward with a clear vision and a righteous mission\n',
#   'to make America great again for all Americans\n',
#   'Over the last year we have made incredible progress and achieved\n',
#   'extraordinary success\n',
#   'We are faced challenges. We expected and others we could never have imagined\n',
#   'We have shared in the heights of victory and the pains of hardship\n',
#   'We have endured floods and fires and storms\n',
#   "But through it all we have seen the beauty of America soul and the steel in America's spine\n",
#   'each test has forged new American heroes to remind us who we are and\n',
#   'Show us what we can be\n',
#   'We saw the volunteers of the Cajun Navy\n',
#   'Racing to the rescue with their fishing boats to save people in the aftermath of a totally\n',
#   'devastating hurricane\n',
#   'We saw strangers shielding strangers from a hail of gunfire on the Las Vegas Strip\n',
#   'We heard tales of Americans like Coast Guard Petty Officer Ashley Leppard\n',
#   'Who is here tonight in the gallery with melania?\n',
#   'Ashley was aboard one of the first helicopters on the scene in Houston during the hurricane Harvey\n',
#   'through 18 hours of wind and rain\n',
#   'Ashley braved live power lines and deep water to help save more than 40 lives\n',
#   'Ashley we all thank you, thank you very much\n',
#   'We heard about Americans like firefighter David Dahlberg\n',
#   "He's here with us also\n",
#   'David faced down walls of flame to rescue almost 60 children trapped at a California summer camp\n',
#   'threatened by those devastating wildfires\n',
#   'to everyone still recovering in Texas, Florida, Louisiana, Puerto Rico and the Virgin Islands\n',
#   'Everywhere we are with you we love you and we always will pull through together always\n',
#   'Thank you to David and the brave people of California, thank you very much David great job\n',
#   'Some trials over the past year touched this chamber very personally\n',
#   'with us tonight is one of the toughest people ever to serve in this house a\n',
#   'guy who took a bullet\n',
#   'Almost died and was back to work three and a half months later\n',
#   'the legend from Louisiana\n',
#   'Congressman Steve, Scalise\n',
#   'I\n',
#   'Think they like you Steve\n',
#   "We're incredibly grateful for the heroic efforts of the Capitol Police Officers the\n",
#   'Alexandria Police and the doctors nurses and paramedics who saved his life and the lives of many others\n',
#   'some in this room in\n',
#   'The aftermath yes\n',
#   'In the aftermath of that terrible shooting we came together not as Republicans or Democrats\n',
#   'but as\n',
#   'representatives of the people\n',
#   'But it is not enough to come together only in times of tragedy tonight. I\n',
#   'Call upon all of us to set aside our differences\n',
#   'To seek out common ground and to summon the unity we need to deliver for the people\n',
#   'This is really the key these are the people we were elected to serve\n',
#   'Thank you\n',
#   'Over the last year the world has seen\n',
#   'What we always know that no people on earth are so fearless or daring or determine as\n',
#   "Americans if there is a mountain we climb it if there's a frontier we cross it\n",
#   "if there's a challenge we tame it if\n",
#   "There's an opportunity we seize it\n",
#   "So let's begin tonight by\n",
#   'Recognizing that the state of our union is strong\n',
#   'Because our people are strong\n',
#   'And together we are building a safe strong and proud\n',
#   'America. Since the election we have created 2.4 million new jobs\n',
#   'including\n',
#   'Including 200,000 new jobs in manufacturing alone tremendously\n',
#   'After years and years of wage stagnation. We are finally seeing rising wages\n',
#   'Unemployment claims have hit a 45 year low and\n',
#   "Something I'm very proud of african-american unemployment stands at the lowest rate ever recorded\n",
#   'And Hispanic American unemployment has also reached the lowest levels in history\n',
#   'Small business confidence is at an all-time high\n',
#   'The stock market has smashed one record after another\n',
#   'gaining 8 trillion dollars and more in value in just this short period of time\n',
#   'the great news\n',
#   'The great news for Americans\n',
#   '401k retirement\n',
#   'pension and college savings accounts have gone through the roof and\n',
#   'Just as I promised the American people from this podium 11 months ago\n',
#   'We enacted the biggest tax cuts and reforms in American history\n',
#   'Our massive tax cuts provide tremendous relief for the middle class and small business\n',
#   'to lower tax rates\n',
#   'for hardworking Americans\n',
#   'We nearly doubled the standard deduction for everyone\n',
#   'Now the first $24,000 earned by a married couple is completely tax-free\n',
#   'We also doubled the child tax credit\n',
#   'The typical family of four making\n',
#   '$75,000 will see their tax bill reduced by $2,000 slashing their tax bill in half\n',
#   'In April, this will be the last time you will ever file under the old and very broken system and\n',
#   'millions of Americans will have more take-home pay\n',
#   'Starting next month a lot more\n',
#   'We eliminated an especially cruel tax that fell mostly on Americans making less than\n',
#   "$50,000 a year forcing them to pay tremendous penalties simply because they couldn't afford\n",
#   'Government ordered health plans we repealed the core of the disastrous\n',
#   'Obamacare the individual mandate is now gone\n',
#   'We slashed the business tax rate from 35 percent all the way down to 21 percent\n',
#   'So American companies can compete and win against anyone else anywhere in the world\n',
#   'These changes alone are estimated to increase\n',
#   'average family income\n',
#   'by more than four thousand dollars a\n',
#   'lot of money\n',
#   'Small businesses have also received a massive tax cut and can now deduct 20 percent of their business\n',
#   'income\n',
#   'here tonight our Steve Stoute and\n',
#   'Sandy Keplinger of\n',
#   'stout\n',
#   'manufacturing a small\n',
#   'beautiful business in Ohio\n',
#   "They've just finished the best year in their 20 year history\n",
#   'Because of tax reform they are handing out raises hiring an additional 14 people and\n',
#   'Expanding into the building next door\n',
#   'good feeling\n',
#   'One of stabs employees Corey Adams is also with us tonight\n',
#   'Corey is an\n',
#   'all-american worker\n',
#   'he supported himself through high school lost his job during the\n',
#   '2008 recession and was later hired by stabbed where he trained to become a welder\n',
#   'like many hardworking Americans\n',
#   'Corey plans to invest his tax cut raise\n',
#   'Into his new home and his two daughters\n',
#   'education Corey, please stand\n',
#   'And\n',
#   "he's a great welder I\n",
#   "Was told that by the man that owns that company. That's doing so well so congratulations Cory\n",
#   'Since we passed tax cuts roughly three million workers have already gotten tax cut\n',
#   'bonuses many of them thousands and thousands of dollars per worker\n',
#   "And it's getting more every month every week Apple has just announced it plans to invest a total of\n",
#   '350 billion dollars in America and hire another 20,000 workers\n',
#   'Just a little while ago\n',
#   'ExxonMobil announced a fifty billion dollar investment in the United States just a little while\n',
#   'This in fact is our new American moment there has never been a better time to start living\n',
#   'The American dream so to every citizen watching at home tonight\n',
#   "No matter where you've been or where you've come from\n",
#   'This is your time\n',
#   'If you work hard if you believe in yourself\n',
#   'if you believe in America then you can dream anything you can be anything and\n',
#   'Together we can achieve\n',
#   'absolutely anything\n',
#   "Tonight I want to talk about what kind of future we're going to have and what kind of a nation we're going to be\n",
#   'All of us together as one team one people and one\n',
#   'American family can do anything\n',
#   'we all share the same home the same heart the same destiny and\n',
#   'the same great American flag\n',
#   'Together we are rediscovering\n',
#   'The American Way in America we know that faith and family not government and bureaucracy\n',
#   'or the center of American life\n',
#   'The motto is In God, We Trust\n',
#   'And\n',
#   'we celebrate our police our military and our amazing veterans as heroes who deserve our total and\n',
#   'unwavering support\n',
#   'Here tonight is Preston sharp a\n',
#   '12 year old boy from Redding, California\n',
#   'Who noticed that Veterans graves?\n',
#   'Were not marked with flags on Veterans Day\n',
#   'He decided role by himself to change that and started a movement that has now placed\n',
#   '40,000 flags at the graves of our great heroes Preston a job well done\n',
#   'Young Patriots like Preston teach all of us about our civic duty as\n',
#   'America and I met past in a little while ago, and he is something very special that I can tell you great future\n',
#   "Thank you very much for all you've done Preston. Thank you very much\n",
#   "Preston's reverence for those who have served our nation reminds us of why we salute our flag?\n",
#   'Why we put our hands on our hearts?\n',
#   'For the pledge of allegiance, and why we proudly stand for the national anthem\n',
#   'Americans love their country, and they deserve a government that shows them the same love and\n',
#   'loyalty in return. For the last year we have sought to restore the bonds of trust between our citizens and their government\n',
#   'Working with the Senate. We are appointing judges who will interpret the Constitution as written\n',
#   'including a great new Supreme Court justice and more Circuit Court judges than any new\n',
#   'administration in the history of our country\n',
#   'We are totally defending our Second Amendment and have taken historic actions to protect religious liberty\n',
#   'And we are serving our brave veterans including giving our veterans choice in their health care decisions\n',
#   'Last year Congress also passed and I signed the landmark va. Accountability Act\n',
#   'Since its passage my administration has already removed more than\n',
#   '1500 VA employees who fail to give our veterans the care they deserve and we are hiring\n',
#   'Talented people who love our vets as much as we do\n',
#   'And I will not stop until our veterans are properly taken care of which has been my promise to them\n',
#   'from the very beginning of\n',
#   'this great journey\n',
#   'All Americans deserve\n',
#   "Accountability and respect and that's what we are giving to our\n",
#   'Wonderful heroes our veterans. Thank you\n',
#   'So tonight I call on Congress to empower every cabinet secretary with the\n',
#   'authority to reward good workers and to remove federal employees who undermine the public trust or\n',
#   'fail the American people\n',
#   'In our drive to make Washington accountable we have eliminated more regulations in our first year than any\n',
#   'Administration in the history of our country\n',
#   'We have ended the war on American energy and we have ended the war on\n',
#   'beautiful clean coal\n',
#   'We are now very proudly an exporter of energy to the world\n',
#   'In Detroit I\n',
#   "Halted government mandates that crippled America's great\n",
#   'beautiful Auto Workers\n',
#   "So that we can get Motor City revving its engines again, and that's what's happening\n",
#   'Many car companies are now building and expanding plants in the United States\n',
#   "Something we haven't seen for decades\n",
#   'Chrysler is moving a major plant from Mexico to Michigan\n',
#   'Toyota and Mazda are opening up a plant in Alabama a big one\n',
#   "And we haven't seen this in a long time\n",
#   "It's all coming back\n",
#   'Very soon auto plants and other plants will be opening up all over our country\n',
#   'This is all news\n',
#   'Americans are\n',
#   'Totally unaccustomed to here for many years companies and jobs were only leaving us\n',
#   'but now\n',
#   "They are roaring back. They're coming back\n",
#   "They want to be where the action is they want to be in the United States of America. That's what they want\n",
#   'Exciting progress is happening every single day\n',
#   'to speed access\n',
#   'To breakthrough cures and affordable generic drugs last year the FDA\n',
#   "Approved more new and generic drugs and medical devices than ever before in our country's history\n",
#   'We also believe that patients\n',
#   'with terminal conditions\n',
#   'terminal illness\n',
#   'should have access to\n',
#   'Experimental treatment immediately that could potentially save their lives\n',
#   'people who are terminally ill\n',
#   'should not have to go from country to country to seek a cure I\n',
#   "Want to give them a chance right here at home. It's time for Congress to give these\n",
#   'wonderful incredible Americans the right to\n',
#   'try\n',
#   'One of my greatest priorities is to reduce the price of prescription drugs\n',
#   'In many other countries these drugs cost far less\n',
#   "Than what we pay in the United States, and it's very very unfair\n",
#   "That is why I've directed my administration to make fixing the injustice of high drug prices\n",
#   'one of my top priorities for the year\n',
#   'And prices will come down substantially watch\n',
#   'America has also finally turned the page on decades of unfair trade deals that\n',
#   'sacrificed our prosperity and shipped away our companies our jobs and our\n',
#   'wealth our\n',
#   "Nation has lost its wealth, but we're getting it back so fast the era of economic\n",
#   'surrender is totally over from now on we expect trading relationships to be fair and\n',
#   'very importantly\n',
#   'reciprocal\n',
#   'We will work to fix bad trade deals and\n',
#   "Negotiate new ones, and they'll be good ones, but they'll be fair and we will protect\n",
#   'American workers and American\n',
#   'intellectual property\n',
#   'through strong enforcement of our trade rules\n',
#   'As we rebuild our industries it is also time to rebuild our crumbling infrastructure\n',
#   'America is a nation of builders. We built the Empire State Building in just one year\n',
#   "Isn't it a disgrace that it can now take ten years just to get a minor permit approved\n",
#   'for the building of a simple road\n',
#   'I\n',
#   'Am asking both parties to come together to give us safe fast reliable and modern infrastructure that our\n',
#   'Economy needs and our people deserve\n',
#   "Tonight I'm calling on Congress to produce a bill that generates at least\n",
#   '1.5 trillion dollars for the new infrastructure investment that our country so desperately needs\n',
#   'every federal dollar\n',
#   'Should be leveraged by partnering with state and local governments and where appropriate\n',
#   'Tapping into private sector investment to permanently fix the infrastructure deficit and we can do it\n',
#   'Any bill\n',
#   'must also streamline the permitting and approval process getting it down to no more than two years and\n',
#   'perhaps even one\n',
#   'Together we can reclaim our great building heritage\n',
#   'We will build\n',
#   'gleaming new roads bridges highways\n',
#   'Railways and waterways all across our land, and we will do it\n',
#   'with American Heart and American hands and\n',
#   'American grit\n',
#   "We want every American to know the dignity of a hard day's work\n",
#   'We want every child to be safe in their home at night\n',
#   'And we want every citizen to be proud of this land that we all love so much\n',
#   'We can lift our citizens from welfare to work\n',
#   'from dependence to independence\n',
#   'and from poverty to prosperity\n',
#   'As tax cuts create new jobs\n',
#   "Let's invest in Workforce Development, and let's invest in job training, which we need so bad room\n",
#   "Let's open great\n",
#   'vocational schools so our future workers can learn a craft and realise their full potential\n',
#   "And let's support working families by supporting paid family leave\n",
#   'As America regains its strength\n',
#   'Opportunity must be extended to all citizens\n',
#   'That is why this year we will embark on reforming our prisons to help former inmates who have served their time\n',
#   'Get a second chance at life\n',
#   'Struggling communities\n',
#   'Especially immigrant communities will also be helped by immigration policies that focus on the best\n',
#   'interests of American workers and American families\n',
#   'For decades open borders have allowed drugs and gangs\n',
#   'to pour into our\n',
#   'most vulnerable communities\n',
#   "They've allowed millions of low-wage workers to compete for jobs and wages\n",
#   'Against the poorest Americans most tragically they have caused the loss of many innocent lives\n',
#   'Here tonight our two fathers, and two mothers Evelyn Rodriguez Freddie Cuevas\n',
#   'Elisabeth Alvarado and Robert nickens their two teenage daughters\n',
#   "Kayla Cuevas and Nisa Mickey's were close friends on Long Island\n",
#   'but in September\n',
#   "2016 on the eve of niece's\n",
#   '16th birthday such a happy time it should have been\n',
#   'neither of them\n',
#   'came home\n',
#   'These two precious girls were brutally murdered while walking together in their hometown\n',
#   'six members of the savage\n',
#   'ms-13 gang\n',
#   'have been charged with Kayla and\n',
#   'Nieces murders many of these gang members took advantage of glaring loopholes in our laws\n',
#   'to enter the country as\n',
#   'illegal\n',
#   'unaccompanied alien minors and wound up in\n',
#   "Kayla and niece's high school\n",
#   'Evelyn Elizabeth Freddie and Robert tonight everyone in this chamber is praying for you\n',
#   'Everyone in America is grieving for you. Please stand. Thank you very much\n',
#   'I want you to know that\n',
#   '320 million hearts are right now breaking for you. We love you. Thank you\n',
#   'Well we cannot imagine the depths of that kind of sorrow we can make sure that other families never have\n',
#   'to endure this kind of pain\n',
#   'Tonight I am calling on Congress to finally close the deadly loopholes that have allowed\n',
#   'ms-13 and other criminal gangs to break into our country\n',
#   'We have proposed new legislation\n',
#   'That will fix our immigration laws and support our ice and Border Patrol agents\n',
#   'These are great people these are great great people that work so hard in the midst of such\n',
#   'danger\n',
#   'so that this can never\n',
#   'happen again\n',
#   'The United States is a compassionate nation\n',
#   'We are proud that we do more than any other country\n',
#   'Anywhere in the world to help the needy the struggling and the underprivileged all over the world\n',
#   'But as president of the United States my highest loyalty my greatest\n',
#   'Compassion my constant concern is for\n',
#   "America's children\n",
#   "America's struggling workers and America's forgotten communities I\n",
#   'Want our youth to grow up to achieve great things?\n',
#   'I want our poor to have their chance to rise\n',
#   'So tonight, I am extending an open hand to work with members of both parties\n',
#   'Democrats and Republicans to protect our citizens of every background color religion and Creed\n',
#   'My duty and the sacred duty of\n',
#   'Every elected official in this chamber is to defend Americans\n',
#   'To protect their safety their families their communities and their right to the American Dream\n',
#   'Because Americans are dreamers, too\n',
#   'Here tonight is one leader in the effort to defend our country\n',
#   'Homeland Security Investigations\n',
#   'special agent\n',
#   'Celestino Martinez he goes by\n',
#   'DJ and\n',
#   'CJ he said call me either one\n',
#   "So we'll call you CJ\n",
#   'sir 15 years in the Air Force before becoming an ice agent and\n',
#   'Spending the last 15 years fighting gang violence and getting dangerous criminals off of our streets\n',
#   'tough job at one point\n',
#   "Ms-13 leaders ordered CJ's murder, and they wanted it to happen quickly\n",
#   'But he did not cave to threats or to fear\n',
#   'Last May he commanded an operation to track down gang members on Long Island his team has arrested nearly\n',
#   '400 including more than\n',
#   '220\n',
#   'ms-13 gang members\n',
#   'And I have to tell you what the Border Patrol and ice have done. We have sent\n',
#   'thousands and thousands and thousands of\n',
#   'ms-13\n',
#   'horrible people out of this country or into our prisons\n',
#   "So I just want to congratulate you CJ. You're a brave guy. Thank you very much\n",
#   "And is CJ what's the secret he said we're just tougher than they are and I like that is\n",
#   "Now let's get Congress to send you and\n",
#   'All of the people in this great chamber have to do it we have no choice\n',
#   "CJ we're going to send you\n",
#   "Reinforcements and we're going to send them to you quickly that's what your name\n",
#   'Over the next few weeks the House and Senate will be voting on an immigration reform\n',
#   'Package in recent months my administration has met extensively with both Democrats and Republicans\n',
#   'To craft a bipartisan approach to immigration reform\n',
#   'Based on these discussions we presented Congress with a detailed proposal that should be supported\n',
#   'By both parties as a fair compromise one. Where nobody gets everything they want\n',
#   'But where our country gets the critical\n',
#   'reforms it needs and must have\n',
#   'Here are the four pillars of our plan\n',
#   'the first pillar of our framework\n',
#   'generously offers a path to\n',
#   'citizenship\n',
#   'For 1.8. Million illegal immigrants who were brought here by their parents at a young age\n',
#   'That covers almost\n',
#   'three times more people than the previous administration\n',
#   'covered\n',
#   'Under our plan those who meet education and work requirements and show good moral character\n',
#   'will be able to become full citizens of the United States over a 12-year period\n',
#   'The second pillar fully secures the border\n',
#   'That means building a great wall on the southern border and it means hiring more heroes like CJ to keep\n',
#   'our communities safe\n',
#   'Crucially our plan closes the terrible loopholes\n',
#   'exploited by criminals and terrorists to enter our country, and it finally ends the horrible and\n',
#   'dangerous practice of catch and release\n',
#   'The third pillar\n',
#   'Ends the visa lottery a program that randomly hands out green cards without any regard for skill\n',
#   'merit or the safety of\n',
#   'American people\n',
#   "It's time to begin moving toward a merit-based\n",
#   'immigration system one that admits people who are skilled who want to work who will contribute to our society and\n',
#   'Who will love and respect our country?\n',
#   'The fourth and final pillar protects the nuclear family by ending chain migration\n',
#   'Under the current broken system a single immigrant can bring in virtually unlimited\n',
#   'numbers of\n',
#   'distant relatives\n',
#   'under our plan\n',
#   'We focus on the immediate family by limiting sponsorships to spouses and minor children\n',
#   'This vital reform is necessary not just for our economy, but for our security and\n',
#   'for the future of America\n',
#   'in\n',
#   'Recent weeks two terrorist attacks in New York were made possible by the Visa Lottery and chain migration\n',
#   'In the age of terrorism these programs present risks we can just no longer\n',
#   'afford\n',
#   "It's time to reach for\n",
#   'These outdated\n',
#   'immigration rules and\n',
#   'Finally bring our immigration system into the 21st century\n',
#   'These four pillars\n',
#   'Represent a down the middle compromise and one that will create a safe modern and lawful\n',
#   'immigration system\n',
#   'for over 30 years\n',
#   'Washington has tried and failed to solve this problem this Congress can be the one\n',
#   'that finally\n',
#   'makes it happen\n',
#   'most importantly these four pillars\n',
#   'will produce legislation that fulfills my\n',
#   'ironclad pledge\n',
#   'to sign a bill that puts\n',
#   'America first\n',
#   "So let's come together\n",
#   'set politics aside and\n',
#   'Finally get the job done\n',
#   'These reforms will also support our response to the terrible crisis of\n',
#   'Opioid and drug addiction never before has it been like it is now it is terrible\n',
#   'We have to do something about it in\n',
#   '2016 we lost\n',
#   '64 thousand Americans to drug overdoses\n',
#   '174 deaths per day\n',
#   'seven per hour\n',
#   'We must get much tougher on drug dealers and pushers\n',
#   'If we are going to succeed in stopping this scourge\n',
#   'My administration is committed\n',
#   'To fighting the drug epidemic and helping get treatment for those in need\n',
#   'For those who have been so terribly hurt\n',
#   'The struggle will be long and it will be difficult\n',
#   'But as Americans always do in the end we will succeed we will prevail\n',
#   'As\n',
#   'We have seen tonight the most difficult challenges bring out the best in America\n',
#   'we see a\n',
#   "vivid expression of this truth in the story of the ohlet's family of New Mexico\n",
#   "Ryan ha let's is 27 years old an officer with the Albuquerque Police Department\n",
#   "He's here tonight with his wife Rebecca\n",
#   'Thank You Ryan\n',
#   'Last year Ryan was on duty when he saw a pregnant homeless woman preparing to inject heroin\n',
#   'When Ryan told her she was going to harm her unborn child\n',
#   "She began to weep she told him she didn't know where to turn\n",
#   'But badly wanted a safe home for her, baby\n',
#   'In that moment Ryan said he felt God speak to him you will do it\n',
#   'Because you can he heard those words\n',
#   'He took out a picture of his wife and their four kids\n',
#   'Then he went home to tell his wife\n',
#   'Rebecca in an instant she agreed to adopt\n',
#   "The whole let's named\n",
#   'their new daughter hope\n',
#   'Ryan and Rebecca\n',
#   'You embody the goodness of our nation? Thank you\n',
#   'Thank You Ryan and Rebecca\n',
#   'as\n',
#   "We rebuild America's strength and confidence at home. We are also restoring our strength and standing abroad\n",
#   'Around the world we face rogue regimes\n',
#   'terrorist groups and\n',
#   'rivals like China and Russia\n',
#   'That challenge our interests our economy and our values in confronting these\n',
#   'horrible dangers we know that weakness is the surest path to conflict and\n',
#   'Unmatched power is the surest means to our true and great defense\n',
#   'for this reason I am asking Congress to end the\n',
#   'dangerous defense sequester and fully fund our great\n',
#   'military\n',
#   'As\n',
#   'part of our defense\n',
#   'We must modernize and rebuild our nuclear arsenal\n',
#   'Hopefully never having to use it, but making it so strong and so powerful\n',
#   'That it will deter any acts of aggression by any other nation or anyone else\n',
#   'Perhaps someday in the future there will be a magical moment\n',
#   'When the countries of the world will get together to eliminate\n',
#   'their nuclear weapons\n',
#   'Unfortunately we are not there yet sadly\n',
#   'Last year I also pledged that we would work with our allies to extinguish Isis\n',
#   'from the face of the earth\n',
#   'One year later. I am proud to report that\n',
#   'The coalition to defeat Isis has liberated\n',
#   'Very close to 100% of the territory\n',
#   'Just recently held\n',
#   'By these killers in Iraq and in Syria and in other locations as well\n',
#   'But there is much more work to be done. We will continue our fight until Isis is defeated\n',
#   'Army Staff Sergeant Justin Peck is here tonight\n',
#   'near, Raqqa last November\n',
#   'Justin and his\n',
#   'comrade chief petty officer Kenton Stasi\n',
#   "We're on a mission to clear buildings that Isis had rigged\n",
#   'with explosives\n',
#   'so that civilians could\n',
#   'Return to that city hopefully soon, and hopefully safely\n',
#   'Clearing the second floor of a vital hospital Kenton Stasi was severely wounded\n',
#   'by an explosion\n',
#   'immediately Justin bounded into the booby-trapped and\n',
#   'Unbelievably dangerous and unsafe building and\n',
#   'Found Kenton but in very very bad shape\n',
#   'he applied pressure to the wound and\n',
#   'inserted a tube\n',
#   'to reopen an airway\n',
#   'He then performed\n',
#   'CPR\n',
#   'for 20 straight minutes\n',
#   'during the ground transport and\n',
#   'maintained\n',
#   'artificial respiration\n',
#   'through two and a half hours and\n',
#   'through emergency surgery\n',
#   'Kenton Stacy\n',
#   'would have died\n',
#   "If it were not for Justin's selfless love\n",
#   'for his fellow warrior tonight\n',
#   'Kenton is\n',
#   'recovering in Texas\n',
#   'Raqqa is liberated and\n',
#   'Justin is wearing his new Bronze Star\n',
#   'with a V for valor Staff Sergeant heck all of America see\n',
#   'Terrorists who do things like place bombs in civilian hospitals are evil when possible\n',
#   'we have no choice, but to\n',
#   'annihilate them when necessary\n',
#   'We must be able to detain and question\n',
#   'them\n',
#   'But we must be clear\n',
#   'Terrorists are not merely criminals. They are unlawful enemy\n',
#   'combatants\n',
#   'And\n',
#   'When captured overseas they should be treated like the terrorists\n',
#   'They are in the past we have foolishly released\n',
#   'hundreds and hundreds of dangerous terrorists\n',
#   'Only to meet them again\n',
#   'on the\n',
#   'battlefield\n',
#   'including the Isis leader\n',
#   'al-baghdadi\n',
#   'Who we captured who we had who we released\n',
#   "So today, I'm keeping another promise. I just signed\n",
#   'prior to walking in an\n',
#   'order directing\n',
#   'Secretary mattis who is doing a great job. Thank you\n',
#   'To re-examine our military detention policy and to keep open the detention\n',
#   'facilities in Guantanamo Bay\n',
#   'I am asking Congress to ensure\n',
#   'That in the fight against Isis and al-qaeda\n',
#   'We continue to have all necessary power\n',
#   'To detain terrorists wherever we chase them down\n',
#   'Wherever we find them\n',
#   'and in many cases for them it will now be\n',
#   'Guantanamo Bay\n',
#   'At the same time as of a few months ago\n',
#   'our warriors in Afghanistan have new rules of engagement\n',
#   'Along with their heroic Afghan partners our military is no longer undermined\n',
#   'By artificial timelines, and we no longer tell our enemies our plans\n',
#   'Last month I also took an action endorsed unanimously by the US Senate just months before I\n',
#   'recognized\n',
#   'Jerusalem as the capital of Israel\n',
#   'Shortly afterwards dozens of countries voted in the United Nations General Assembly\n',
#   "against America's sovereign right to make this decision in\n",
#   '2016 American taxpayers\n',
#   'Generously sent those same countries more than twenty billion dollars in aid\n',
#   'That is why tonight I am asking Congress to pass legislation\n',
#   'to help ensure\n',
#   'American foreign assistance dollars\n',
#   'always serve American interests and\n',
#   'Only go to Friends of America not enemies\n',
#   'As we strengthen\n',
#   'Friendships all around the world we are also restoring clarity\n',
#   'about our\n',
#   'adversaries when the people of Iran rose up against the crimes of their corrupt\n',
#   'Dictatorship, I did not stay silent\n',
#   'America stands with the people of Iran in their courageous struggle for freedom\n',
#   'I am asking Congress to address the fundamental flaws in the terrible Iran\n',
#   'nuclear deal\n',
#   'My administration has also imposed tough sanctions on the communist and socialist\n',
#   'dictatorships in Cuba and Venezuela\n',
#   'But no regime\n',
#   'Has oppressed its own citizens more totally or brutally?\n',
#   'than the cruel dictatorship in North Korea\n',
#   "North Korea's reckless pursuit of nuclear missiles\n",
#   'Could very soon threaten our homeland. We are waging a campaign of\n',
#   'maximum pressure to prevent that from ever happening\n',
#   'Past experience has taught us that\n',
#   'complacency and concessions\n',
#   'only invite aggression and\n',
#   'Provocation, I will not repeat the mistakes of past\n',
#   'Administrations that got us into this very dangerous\n',
#   'position\n',
#   'We need only look at the depraved character of the North Korean regime to understand the nature of\n',
#   'the nuclear threat\n',
#   'It could pose\n',
#   'to America and to our allies\n',
#   'otto warmbier\n',
#   'Was a hard-working student at the University of\n',
#   'Virginia and a great student. He was on his way to study\n',
#   'abroad in Asia otto joined a tour\n',
#   'to North Korea at its conclusion this wonderful young man was arrested and\n',
#   'charged with crimes\n',
#   'against the state\n',
#   'After a shameful trial\n',
#   'the dictatorship sentenced otto\n',
#   'to 15 years of hard labor\n',
#   'Before returning him to America last June\n',
#   'horribly injured and on the verge of death\n',
#   'He passed away\n',
#   'Just days after his return\n',
#   "Otto's\n",
#   'Wonderful parents\n',
#   'Fred and Cindy warmbier\n',
#   "Are here with us tonight along with Otto's brother and sister\n",
#   'Austin and\n',
#   'Greta please\n',
#   'Credible people\n',
#   'You are powerful witnesses to a menace that threatens our world and your strength truly\n',
#   'Inspires us all. Thank you very much\n',
#   "Tonight we pledge to honor Otto's memory with\n",
#   'Total American resolve, thank you\n',
#   'finally\n',
#   'We are joined by one more witness to the ominous nature of this regime\n',
#   'His name is mr.. Ji sung ho\n',
#   'in\n',
#   '1996 sung ho was a starving boy in North Korea\n',
#   'One day he tried to steal coal\n',
#   'From a railroad car to barter for a few scraps of food\n',
#   'Which were very hard to get in the process he passed out on the train tracks\n',
#   'exhausted from hunger\n',
#   'He woke up as a train\n',
#   'ran over his limbs\n',
#   'He then endured multiple amputations without anything to dull the pain or the hurt\n',
#   'His brother and sister gave what little food. They had to help him recover and\n',
#   'ate dirt\n',
#   'themselves\n',
#   'permanently stunting their own growth\n',
#   'Later he was tortured by North Korean authorities after returning from a brief visit to China\n',
#   'His tormentors wanted to know\n',
#   "if he'd met any\n",
#   'Christians\n',
#   'He had and he resolved after that to be free\n',
#   'Seung ho travel thousands of miles on crutches all across China and\n',
#   'Southeast Asia to freedom\n',
#   'Most of his family followed his father was caught trying to escape and was tortured to death\n',
#   'Today he lives in Seoul where he rescues other defectors and\n',
#   'Broadcasts into North Korea what the regime fears?\n',
#   'most the truth\n',
#   'Today he has a new leg\n',
#   'But somehow I understand you still keep\n',
#   'those old crutches as a reminder of\n',
#   "How far you've come?\n",
#   'Your great sacrifice is an inspiration\n',
#   'To us all please, thank you\n',
#   "Seungho's story is a testament to the yearning of every human soul to live in freedom\n",
#   'It was that same yearning for freedom that nearly two hundred and fifty years ago gave birth to a special place\n',
#   'called America\n',
#   'It was a small cluster of colonies caught between a great ocean and a vast wilderness\n',
#   'It was home to an incredible people\n',
#   'with a\n',
#   'revolutionary idea that\n',
#   'They could rule\n',
#   'themselves. That they could chart their own destiny and that\n',
#   'together\n',
#   'They could light up the entire world\n',
#   'That is what our country has always been about\n',
#   'That is what Americans have always stood for\n',
#   'always strived for and\n',
#   'always done\n',
#   'atop the dome of this Capitol\n',
#   'stands the statue of freedom\n',
#   'She stands tall and dignified among\n',
#   'The monuments to our ancestors who fought and lived and died to protect her\n',
#   'monuments to Washington and Jefferson and Lincoln and King\n',
#   'Memorials to the heroes of Yorktown and\n',
#   'Saratoga\n',
#   'to young Americans who shed their blood\n',
#   'on the shores of Normandy and\n',
#   'the fields beyond and\n',
#   'others who went down in the waters of the Pacific and\n',
#   'the skies\n',
#   'all over Asia and\n',
#   'freedom stands tall\n',
#   'Over one more monument this one\n',
#   'This Capitol this living monument. This is the monument to the American people?\n',
#   "We're a people whose heroes live not only in the past\n",
#   'but all around us defending hope pride and\n',
#   'defending the American Way\n',
#   'They work in every trade they sacrifice to raise a family\n',
#   'They care for our children at home\n',
#   'they defend our flag abroad and\n',
#   'they are strong moms and\n',
#   'brave kids. They are firefighters and police officers and border agents medics and Marines\n',
#   'but above all else\n',
#   'They are Americans and this capital this city this nation\n',
#   'belongs entirely to them\n',
#   'Our task is to respect them\n',
#   'to listen to them to serve them to protect them and to\n',
#   'Always be worthy of them\n',
#   'Americans fill the world with art and music\n',
#   'they push the bounds of\n',
#   'science and\n',
#   'discovery and they forever remind us of\n',
#   'What we should never ever?\n',
#   'forget\n',
#   'The people dreamed this country the people\n',
#   "Built this country, and it's the people who are making\n",
#   'America great again\n',
#   'As long as we are proud of who we are and\n',
#   'What we are fighting for?\n',
#   'There is nothing we cannot achieve as\n',
#   'Long as we have confidence in our values\n',
#   'faith in our citizens and\n',
#   'trust in our God\n',
#   'We will never fail\n',
#   'our families will thrive our\n',
#   'People will prosper and our nation\n',
#   'Will forever be safe and strong and proud and mighty and free\n',
#   'Thank you, and God bless\n',
#   'america good night'],
#  'linebreak': ['\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   ''],
#  'time': ['00:00:00,279 --> 00:00:02,169\n',
#   '00:00:02,169 --> 00:00:04,169\n',
#   '00:00:04,420 --> 00:00:06,279\n',
#   '00:00:06,279 --> 00:00:11,308\n',
#   '00:00:12,130 --> 00:00:16,469\n',
#   '00:00:17,289 --> 00:00:19,289\n',
#   '00:00:19,720 --> 00:00:25,710\n',
#   '00:00:27,279 --> 00:00:34,769\n',
#   '00:00:35,980 --> 00:00:41,189\n',
#   '00:00:41,860 --> 00:00:48,029\n',
#   '00:00:48,820 --> 00:00:52,229\n',
#   '00:01:15,190 --> 00:01:19,020\n',
#   '00:01:19,570 --> 00:01:21,160\n',
#   '00:01:21,160 --> 00:01:26,160\n',
#   '00:01:26,590 --> 00:01:30,719\n',
#   '00:01:31,150 --> 00:01:35,219\n',
#   '00:01:36,100 --> 00:01:43,109\n',
#   '00:01:43,990 --> 00:01:49,469\n',
#   '00:01:50,050 --> 00:01:52,499\n',
#   '00:01:53,650 --> 00:01:56,669\n',
#   '00:01:57,310 --> 00:02:04,290\n',
#   '00:02:04,960 --> 00:02:06,910\n',
#   '00:02:06,910 --> 00:02:12,540\n',
#   '00:02:13,390 --> 00:02:18,869\n',
#   '00:02:19,360 --> 00:02:23,369\n',
#   '00:02:50,010 --> 00:02:55,459\n',
#   '00:02:56,340 --> 00:02:58,369\n',
#   '00:02:59,190 --> 00:03:05,240\n',
#   '00:03:06,390 --> 00:03:09,619\n',
#   '00:03:28,610 --> 00:03:33,249\n',
#   '00:03:33,950 --> 00:03:35,950\n',
#   '00:03:36,200 --> 00:03:43,479\n',
#   '00:03:44,150 --> 00:03:46,929\n',
#   '00:03:47,960 --> 00:03:54,279\n',
#   '00:03:55,760 --> 00:04:03,189\n',
#   '00:04:26,650 --> 00:04:32,880\n',
#   '00:04:34,420 --> 00:04:39,059\n',
#   '00:04:39,610 --> 00:04:44,639\n',
#   '00:04:45,250 --> 00:04:47,230\n',
#   '00:04:47,230 --> 00:04:51,330\n',
#   '00:04:51,940 --> 00:04:54,420\n',
#   '00:04:55,030 --> 00:04:57,209\n',
#   '00:05:26,590 --> 00:05:28,590\n',
#   '00:05:28,700 --> 00:05:30,700\n',
#   '00:05:32,120 --> 00:05:38,380\n',
#   '00:05:38,690 --> 00:05:45,459\n',
#   '00:05:45,680 --> 00:05:47,680\n',
#   '00:05:48,350 --> 00:05:50,350\n',
#   '00:06:10,439 --> 00:06:16,069\n',
#   '00:06:16,860 --> 00:06:18,300\n',
#   '00:06:18,300 --> 00:06:20,300\n',
#   '00:06:20,430 --> 00:06:26,000\n',
#   '00:06:26,550 --> 00:06:30,199\n',
#   '00:06:31,020 --> 00:06:36,919\n',
#   '00:06:38,069 --> 00:06:43,789\n',
#   '00:07:03,990 --> 00:07:05,990\n',
#   '00:07:06,360 --> 00:07:08,449\n',
#   '00:07:08,880 --> 00:07:15,559\n',
#   '00:07:16,590 --> 00:07:23,479\n',
#   '00:07:23,820 --> 00:07:26,330\n',
#   '00:07:27,000 --> 00:07:29,840\n',
#   '00:07:30,720 --> 00:07:32,720\n',
#   '00:07:33,480 --> 00:07:37,039\n',
#   '00:07:38,100 --> 00:07:40,520\n',
#   '00:07:57,650 --> 00:08:01,880\n',
#   '00:08:02,790 --> 00:08:04,169\n',
#   '00:08:10,320 --> 00:08:12,320\n',
#   '00:08:17,000 --> 00:08:22,779\n',
#   '00:08:27,770 --> 00:08:34,329\n',
#   '00:08:49,290 --> 00:08:54,500\n',
#   '00:09:00,509 --> 00:09:07,339\n',
#   '00:09:22,970 --> 00:09:30,350\n',
#   '00:09:41,329 --> 00:09:44,858\n',
#   '00:09:45,529 --> 00:09:49,148\n',
#   '00:09:49,579 --> 00:09:55,149\n',
#   '00:09:55,670 --> 00:09:57,670\n',
#   '00:10:03,380 --> 00:10:05,919\n',
#   '00:10:06,980 --> 00:10:08,980\n',
#   '00:10:08,990 --> 00:10:13,390\n',
#   '00:10:13,880 --> 00:10:18,820\n',
#   '00:10:19,490 --> 00:10:24,880\n',
#   '00:10:53,170 --> 00:10:58,559\n',
#   '00:10:59,170 --> 00:11:01,170\n',
#   '00:11:01,689 --> 00:11:03,639\n',
#   '00:11:03,639 --> 00:11:07,889\n',
#   '00:11:13,870 --> 00:11:20,849\n',
#   '00:11:28,399 --> 00:11:32,289\n',
#   '00:11:38,529 --> 00:11:40,979\n',
#   '00:11:42,279 --> 00:11:49,739\n',
#   '00:11:57,340 --> 00:11:58,930\n',
#   '00:12:06,580 --> 00:12:09,870\n',
#   '00:12:10,450 --> 00:12:13,140\n',
#   '00:12:31,510 --> 00:12:39,119\n',
#   '00:12:39,940 --> 00:12:45,239\n',
#   '00:12:46,120 --> 00:12:53,070\n',
#   '00:12:53,800 --> 00:12:58,380\n',
#   '00:13:22,170 --> 00:13:29,660\n',
#   '00:13:30,090 --> 00:13:36,619\n',
#   '00:13:42,780 --> 00:13:45,679\n',
#   '00:13:46,200 --> 00:13:48,000\n',
#   '00:13:48,000 --> 00:13:50,960\n',
#   '00:13:51,660 --> 00:13:53,660\n',
#   '00:13:58,800 --> 00:14:06,020\n',
#   '00:14:06,330 --> 00:14:07,380\n',
#   '00:14:07,380 --> 00:14:10,220\n',
#   '00:14:10,740 --> 00:14:12,480\n',
#   '00:14:12,480 --> 00:14:13,590\n',
#   '00:14:13,590 --> 00:14:15,450\n',
#   '00:14:15,450 --> 00:14:17,450\n',
#   '00:14:17,700 --> 00:14:22,369\n',
#   '00:14:43,270 --> 00:14:49,169\n',
#   '00:14:49,930 --> 00:14:52,560\n',
#   '00:14:53,350 --> 00:14:55,350\n',
#   '00:14:58,900 --> 00:15:04,349\n',
# ...
#   '00:37:56,100 --> 00:37:59,360\n',
#   '00:38:00,240 --> 00:38:04,189\n',
#   '00:38:04,740 --> 00:38:06,740\n',
#   '00:38:06,930 --> 00:38:08,930\n',
#   '00:38:09,300 --> 00:38:14,390\n',
#   '00:38:15,030 --> 00:38:22,429\n',
#   '00:38:23,370 --> 00:38:29,839\n',
#   '00:38:30,600 --> 00:38:35,509\n',
#   '00:38:36,510 --> 00:38:41,810\n',
#   '00:38:42,660 --> 00:38:44,660\n',
#   '00:38:45,270 --> 00:38:48,469\n',
#   '00:38:49,200 --> 00:38:52,280\n',
#   '00:38:53,130 --> 00:38:54,840\n',
#   '00:38:54,840 --> 00:38:56,670\n',
#   '00:38:56,670 --> 00:39:03,620\n',
#   '00:39:04,380 --> 00:39:06,769\n',
#   '00:39:07,470 --> 00:39:09,470\n',
#   '00:39:09,480 --> 00:39:12,260\n',
#   '00:39:12,840 --> 00:39:18,919\n',
#   '00:39:19,470 --> 00:39:21,470\n',
#   '00:39:21,930 --> 00:39:23,550\n',
#   '00:39:23,550 --> 00:39:25,350\n',
#   '00:39:28,470 --> 00:39:31,189\n',
#   '00:39:33,150 --> 00:39:34,680\n',
#   '00:39:41,370 --> 00:39:46,339\n',
#   '00:40:34,610 --> 00:40:36,860\n',
#   '00:40:38,310 --> 00:40:43,880\n',
#   '00:40:50,060 --> 00:40:58,029\n',
#   '00:40:58,670 --> 00:41:00,670\n',
#   '00:41:01,580 --> 00:41:06,999\n',
#   '00:41:07,460 --> 00:41:11,230\n',
#   '00:41:11,750 --> 00:41:13,750\n',
#   '00:41:14,240 --> 00:41:20,410\n',
#   '00:41:20,410 --> 00:41:27,729\n',
#   '00:41:28,100 --> 00:41:29,150\n',
#   '00:41:29,150 --> 00:41:31,150\n',
#   '00:41:31,730 --> 00:41:33,730\n',
#   '00:41:51,530 --> 00:41:54,160\n',
#   '00:41:55,070 --> 00:41:59,620\n',
#   '00:42:00,260 --> 00:42:07,300\n',
#   '00:42:07,970 --> 00:42:13,060\n',
#   '00:42:13,520 --> 00:42:17,229\n',
#   '00:42:17,810 --> 00:42:19,430\n',
#   '00:42:19,430 --> 00:42:23,950\n',
#   '00:42:24,710 --> 00:42:28,929\n',
#   '00:42:29,440 --> 00:42:33,669\n',
#   '00:42:34,220 --> 00:42:39,370\n',
#   '00:42:40,220 --> 00:42:48,160\n',
#   '00:43:04,669 --> 00:43:07,659\n',
#   '00:43:08,329 --> 00:43:13,448\n',
#   '00:43:13,969 --> 00:43:20,409\n',
#   '00:43:21,169 --> 00:43:24,039\n',
#   '00:43:43,170 --> 00:43:47,000\n',
#   '00:43:48,060 --> 00:43:50,060\n',
#   '00:43:50,400 --> 00:43:52,110\n',
#   '00:43:52,110 --> 00:43:54,500\n',
#   '00:43:55,230 --> 00:43:56,760\n',
#   '00:43:56,760 --> 00:43:58,760\n',
#   '00:43:59,760 --> 00:44:01,760\n',
#   '00:44:02,010 --> 00:44:07,280\n',
#   '00:44:07,800 --> 00:44:14,569\n',
#   '00:44:15,060 --> 00:44:17,480\n',
#   '00:44:18,240 --> 00:44:24,530\n',
#   '00:44:25,320 --> 00:44:29,240\n',
#   '00:44:30,150 --> 00:44:37,849\n',
#   '00:44:38,220 --> 00:44:40,220\n',
#   '00:44:40,410 --> 00:44:41,760\n',
#   '00:44:41,760 --> 00:44:43,879\n',
#   '00:44:45,210 --> 00:44:50,149\n',
#   '00:44:51,090 --> 00:44:53,809\n',
#   '00:44:54,780 --> 00:44:56,280\n',
#   '00:44:56,280 --> 00:45:01,040\n',
#   '00:45:01,500 --> 00:45:06,919\n',
#   '00:45:28,170 --> 00:45:34,639\n',
#   '00:45:40,890 --> 00:45:44,030\n',
#   '00:45:44,820 --> 00:45:49,549\n',
#   '00:45:50,190 --> 00:45:52,190\n',
#   '00:45:52,800 --> 00:45:56,419\n',
#   '00:46:02,960 --> 00:46:08,409\n',
#   '00:46:08,900 --> 00:46:16,059\n',
#   '00:46:16,700 --> 00:46:21,490\n',
#   '00:46:22,460 --> 00:46:30,280\n',
#   '00:46:30,560 --> 00:46:35,830\n',
#   '00:46:36,350 --> 00:46:39,940\n',
#   '00:46:40,490 --> 00:46:42,819\n',
#   '00:46:56,900 --> 00:46:59,230\n',
#   '00:47:00,020 --> 00:47:02,649\n',
#   '00:47:03,680 --> 00:47:05,950\n',
#   '00:47:06,620 --> 00:47:07,970\n',
#   '00:47:07,970 --> 00:47:14,169\n',
#   '00:47:14,810 --> 00:47:16,810\n',
#   '00:47:17,510 --> 00:47:21,370\n',
#   '00:47:22,460 --> 00:47:24,460\n',
#   '00:47:29,210 --> 00:47:35,649\n',
#   '00:47:36,380 --> 00:47:40,989\n',
#   '00:47:48,050 --> 00:47:51,850\n',
#   '00:48:10,410 --> 00:48:17,809\n',
#   '00:48:18,000 --> 00:48:20,000\n',
#   '00:48:33,250 --> 00:48:36,689\n',
#   '00:48:37,119 --> 00:48:43,979\n',
#   '00:48:44,500 --> 00:48:47,189\n',
#   '00:49:01,110 --> 00:49:03,060\n',
#   '00:49:03,060 --> 00:49:10,159\n',
#   '00:49:10,710 --> 00:49:12,710\n',
#   '00:49:13,230 --> 00:49:15,230\n',
#   '00:49:26,020 --> 00:49:28,469\n',
#   '00:49:29,230 --> 00:49:37,199\n',
#   '00:49:37,390 --> 00:49:40,890\n',
#   '00:49:55,760 --> 00:50:01,929\n',
#   '00:50:12,809 --> 00:50:18,709\n',
#   '00:50:19,500 --> 00:50:20,880\n',
#   '00:50:20,880 --> 00:50:22,710\n',
#   '00:50:22,710 --> 00:50:24,359\n',
#   '00:50:24,359 --> 00:50:32,088\n',
#   '00:50:40,940 --> 00:50:47,260\n',
#   '00:50:47,990 --> 00:50:50,169\n',
#   '00:50:50,839 --> 00:50:51,890\n',
#   '00:50:51,890 --> 00:50:59,500\n',
#   '00:50:59,990 --> 00:51:07,059\n',
#   '00:51:07,549 --> 00:51:09,049\n',
#   '00:51:09,049 --> 00:51:11,049\n',
#   '00:51:15,770 --> 00:51:17,770\n',
#   '00:51:17,990 --> 00:51:19,760\n',
#   '00:51:19,760 --> 00:51:24,159\n',
#   '00:51:32,390 --> 00:51:34,040\n',
#   '00:51:34,040 --> 00:51:40,810\n',
#   '00:51:41,330 --> 00:51:43,330\n',
#   '00:51:43,400 --> 00:51:45,080\n',
#   '00:51:45,080 --> 00:51:52,179\n',
#   '00:51:52,820 --> 00:51:54,560\n',
#   '00:51:54,560 --> 00:51:56,560\n',
#   '00:51:56,600 --> 00:51:59,079\n',
#   '00:51:59,600 --> 00:52:03,159\n',
#   '00:52:03,710 --> 00:52:05,360\n',
#   '00:52:05,360 --> 00:52:07,809\n',
#   '00:52:08,510 --> 00:52:10,510\n',
#   '00:52:24,450 --> 00:52:26,450\n',
#   '00:52:27,090 --> 00:52:29,090\n',
#   '00:52:30,360 --> 00:52:33,799\n',
#   '00:52:43,070 --> 00:52:49,299\n',
#   '00:52:50,150 --> 00:52:56,889\n',
#   '00:52:56,930 --> 00:52:59,409\n',
#   '00:53:00,230 --> 00:53:02,230\n',
#   '00:53:02,750 --> 00:53:06,429\n',
#   '00:53:08,690 --> 00:53:10,690\n',
#   '00:53:11,359 --> 00:53:12,920\n',
#   '00:53:12,920 --> 00:53:17,980\n',
#   '00:53:18,490 --> 00:53:22,419\n',
#   '00:53:37,809 --> 00:53:39,809\n',
#   '00:53:40,180 --> 00:53:46,319\n',
#   '00:53:47,170 --> 00:53:49,619\n',
#   '00:53:50,170 --> 00:53:53,250\n',
#   '00:53:53,250 --> 00:54:00,599\n',
#   '00:54:14,790 --> 00:54:16,470\n',
#   '00:54:16,470 --> 00:54:22,129\n',
#   '00:54:22,740 --> 00:54:24,060\n',
#   '00:54:24,060 --> 00:54:30,799\n',
#   '00:54:31,920 --> 00:54:37,460\n',
#   '00:54:38,670 --> 00:54:42,139\n',
#   '00:55:01,799 --> 00:55:03,799\n',
#   '00:55:03,970 --> 00:55:10,560\n',
#   '00:55:12,220 --> 00:55:16,740\n',
#   '00:55:17,800 --> 00:55:21,810\n',
#   '00:55:22,480 --> 00:55:26,459\n',
#   '00:55:27,520 --> 00:55:33,030\n',
#   '00:55:33,790 --> 00:55:35,999\n',
#   '00:55:36,880 --> 00:55:40,679\n',
#   '00:55:41,620 --> 00:55:45,479\n',
#   '00:55:46,210 --> 00:55:50,640\n',
#   '00:55:51,640 --> 00:55:53,620\n',
#   '00:55:53,620 --> 00:55:55,620\n',
#   '00:55:56,140 --> 00:55:58,140\n',
#   '00:55:58,510 --> 00:56:02,850\n',
#   '00:56:34,730 --> 00:56:36,730\n',
#   '00:56:37,250 --> 00:56:38,480\n',
#   '00:56:38,480 --> 00:56:46,449\n',
#   '00:56:47,390 --> 00:56:50,379\n',
#   '00:56:51,050 --> 00:56:52,880\n',
#   '00:56:52,880 --> 00:56:54,880\n',
#   '00:56:55,190 --> 00:57:02,080\n',
#   '00:57:02,840 --> 00:57:08,979\n',
#   '00:57:09,770 --> 00:57:17,080\n',
#   '00:57:18,080 --> 00:57:21,669\n',
#   '00:57:22,640 --> 00:57:27,759\n',
#   '00:57:28,400 --> 00:57:30,400\n',
#   '00:57:49,400 --> 00:57:50,310\n',
#   '00:57:50,310 --> 00:57:52,230\n',
#   '00:57:52,230 --> 00:57:56,869\n',
#   '00:57:57,300 --> 00:58:02,900\n',
#   '00:58:03,750 --> 00:58:10,669\n',
#   '00:58:25,329 --> 00:58:28,589\n',
#   '00:58:29,739 --> 00:58:33,239\n',
#   '00:58:34,179 --> 00:58:36,179\n',
#   '00:58:36,699 --> 00:58:41,668\n',
#   '00:58:44,349 --> 00:58:51,478\n',
#   '00:58:51,999 --> 00:58:53,999\n',
#   '00:58:54,910 --> 00:58:58,469\n',
#   '00:58:59,169 --> 00:59:02,189\n',
#   '00:59:02,979 --> 00:59:06,629\n',
#   '00:59:07,390 --> 00:59:09,390\n',
#   '00:59:09,489 --> 00:59:15,718\n',
#   '00:59:37,570 --> 00:59:44,730\n',
#   '00:59:46,060 --> 00:59:49,740\n',
#   '00:59:50,500 --> 00:59:52,980\n',
#   '00:59:53,950 --> 00:59:55,570\n',
#   '00:59:55,570 --> 00:59:56,680\n',
#   '00:59:59,770 --> 01:00:03,540\n',
#   '01:00:04,180 --> 01:00:06,100\n',
#   '01:00:06,100 --> 01:00:08,100\n',
#   '01:00:08,920 --> 01:00:13,200\n',
#   '01:00:14,200 --> 01:00:19,649\n',
#   '01:00:20,380 --> 01:00:22,380\n',
#   '01:00:22,840 --> 01:00:26,999\n',
#   '01:00:29,350 --> 01:00:32,789\n',
#   '01:00:33,550 --> 01:00:37,230\n',
#   '01:00:38,410 --> 01:00:40,829\n',
#   '01:00:41,770 --> 01:00:43,770\n',
#   '01:00:43,870 --> 01:00:46,019\n',
#   '01:00:46,690 --> 01:00:48,580\n',
#   '01:00:48,580 --> 01:00:49,900\n',
#   '01:00:49,900 --> 01:00:51,880\n',
#   '01:00:51,880 --> 01:00:53,999\n',
#   '01:00:54,850 --> 01:00:56,350\n',
#   '01:00:56,350 --> 01:00:58,350\n',
#   '01:00:58,660 --> 01:01:00,690\n',
#   '01:01:01,420 --> 01:01:03,659\n',
#   '01:01:05,200 --> 01:01:06,820\n',
#   '01:01:06,820 --> 01:01:08,590\n',
#   '01:01:08,590 --> 01:01:12,480\n',
#   '01:01:13,180 --> 01:01:16,319\n',
#   '01:01:16,990 --> 01:01:18,460\n',
#   '01:01:18,460 --> 01:01:20,440\n',
#   '01:01:20,440 --> 01:01:22,589\n',
#   '01:01:23,230 --> 01:01:26,039\n',
#   '01:01:26,560 --> 01:01:32,850\n',
#   '01:02:25,509 --> 01:02:31,919\n',
#   '01:02:33,220 --> 01:02:35,220\n',
#   '01:02:35,680 --> 01:02:37,680\n',
#   '01:02:38,500 --> 01:02:41,189\n',
#   '01:02:41,950 --> 01:02:43,210\n',
#   '01:02:43,210 --> 01:02:45,210\n',
#   '01:02:46,150 --> 01:02:50,879\n',
#   '01:02:52,299 --> 01:02:54,299\n',
#   '01:03:12,270 --> 01:03:13,990\n',
#   '01:03:13,990 --> 01:03:18,780\n',
#   '01:03:18,780 --> 01:03:22,769\n',
#   '01:03:23,320 --> 01:03:26,489\n',
#   '01:03:27,040 --> 01:03:29,040\n',
#   '01:03:29,619 --> 01:03:30,790\n',
#   '01:03:30,790 --> 01:03:32,290\n',
#   '01:03:32,290 --> 01:03:34,320\n',
#   '01:03:35,170 --> 01:03:36,609\n',
#   '01:03:36,609 --> 01:03:39,869\n',
#   '01:03:40,900 --> 01:03:45,240\n',
#   '01:03:46,240 --> 01:03:48,240\n',
#   '01:03:48,339 --> 01:03:50,339\n',
#   '01:03:50,440 --> 01:03:54,089\n',
#   '01:04:12,859 --> 01:04:19,629\n',
#   '01:04:20,329 --> 01:04:22,329\n',
#   '01:04:34,520 --> 01:04:37,130\n',
#   '01:04:37,770 --> 01:04:40,610\n',
#   '01:04:41,310 --> 01:04:44,149\n',
#   '01:04:44,940 --> 01:04:48,649\n',
#   '01:04:49,890 --> 01:04:51,840\n',
#   '01:04:51,840 --> 01:04:55,159\n',
#   '01:04:56,520 --> 01:04:58,520\n',
#   '01:05:04,260 --> 01:05:07,789\n',
#   '01:05:08,520 --> 01:05:13,099\n',
#   '01:05:20,849 --> 01:05:26,599\n',
#   '01:05:27,089 --> 01:05:33,558\n',
#   '01:05:48,920 --> 01:05:56,139\n',
#   '01:05:57,350 --> 01:05:58,490\n',
#   '01:05:58,490 --> 01:06:01,540\n',
#   '01:06:18,890 --> 01:06:23,859\n',
#   '01:06:24,920 --> 01:06:28,869\n',
#   '01:06:30,140 --> 01:06:32,530\n',
#   '01:06:33,200 --> 01:06:38,859\n',
#   '01:06:39,890 --> 01:06:43,720\n',
#   '01:06:44,600 --> 01:06:46,600\n',
#   '01:06:46,609 --> 01:06:48,609\n',
#   '01:06:49,369 --> 01:06:50,930\n',
#   '01:06:53,150 --> 01:06:56,950\n',
#   '01:07:14,710 --> 01:07:16,710\n',
#   '01:07:17,020 --> 01:07:21,659\n',
#   '01:07:22,540 --> 01:07:24,010\n',
#   '01:07:24,010 --> 01:07:30,060\n',
#   '01:07:30,579 --> 01:07:33,749\n',
#   '01:07:34,869 --> 01:07:40,019\n',
#   '01:07:54,740 --> 01:08:01,310\n',
#   '01:08:01,920 --> 01:08:03,920\n',
#   '01:08:04,140 --> 01:08:09,980\n',
#   '01:08:11,040 --> 01:08:13,189\n',
#   '01:08:26,210 --> 01:08:28,210\n',
#   '01:08:28,250 --> 01:08:32,919\n',
#   '01:08:33,500 --> 01:08:36,939\n',
#   '01:08:38,000 --> 01:08:41,589\n',
#   '01:08:42,259 --> 01:08:48,158\n',
#   '01:08:48,859 --> 01:08:50,659\n',
#   '01:08:53,599 --> 01:08:56,078\n',
#   '01:08:57,170 --> 01:08:58,699\n',
#   '01:08:59,899 --> 01:09:01,899\n',
#   '01:09:02,868 --> 01:09:06,308\n',
#   '01:09:07,040 --> 01:09:10,329\n',
#   '01:09:11,179 --> 01:09:12,889\n',
#   '01:09:12,889 --> 01:09:20,078\n',
#   '01:09:20,658 --> 01:09:22,548\n',
#   '01:09:22,549 --> 01:09:24,549\n',
#   '01:09:24,589 --> 01:09:27,249\n',
#   '01:09:28,460 --> 01:09:30,460\n',
#   '01:09:30,500 --> 01:09:34,629\n',
#   '01:09:36,078 --> 01:09:40,778\n',
#   '01:09:41,420 --> 01:09:43,190\n',
#   '01:09:45,649 --> 01:09:51,818\n',
#   '01:09:52,880 --> 01:09:54,860\n',
#   '01:09:54,860 --> 01:09:56,860\n',
#   '01:09:57,170 --> 01:09:59,170\n',
#   '01:09:59,599 --> 01:10:02,049\n',
#   '01:10:02,750 --> 01:10:05,169\n',
#   '01:10:06,079 --> 01:10:09,429\n',
#   '01:10:10,610 --> 01:10:14,319\n',
#   '01:10:15,710 --> 01:10:17,710\n',
#   '01:10:18,110 --> 01:10:20,259\n',
#   '01:10:22,010 --> 01:10:24,010\n',
#   '01:10:24,739 --> 01:10:26,630\n',
#   '01:10:26,630 --> 01:10:28,630\n',
#   '01:10:29,119 --> 01:10:33,729\n',
#   '01:10:34,520 --> 01:10:36,020\n',
#   '01:10:36,020 --> 01:10:38,020\n',
#   '01:11:15,730 --> 01:11:17,730\n',
#   '01:11:18,580 --> 01:11:25,169\n',
#   '01:11:25,989 --> 01:11:28,049\n',
#   '01:11:51,670 --> 01:11:56,339\n',
#   '01:11:57,670 --> 01:12:02,160\n',
#   '01:12:03,520 --> 01:12:05,520\n',
#   '01:12:10,480 --> 01:12:16,589\n',
#   '01:12:17,260 --> 01:12:20,400\n',
#   '01:12:21,280 --> 01:12:23,080\n',
#   '01:12:23,080 --> 01:12:27,569\n',
#   '01:12:28,300 --> 01:12:30,690\n',
#   '01:12:31,510 --> 01:12:36,540\n',
#   '01:12:36,610 --> 01:12:42,480\n',
#   '01:12:43,660 --> 01:12:45,660\n',
#   '01:12:45,880 --> 01:12:47,880\n',
#   '01:12:48,430 --> 01:12:50,430\n',
#   '01:12:51,160 --> 01:12:57,959\n',
#   '01:12:58,930 --> 01:13:04,109\n',
#   '01:13:04,840 --> 01:13:06,790\n',
#   '01:13:06,790 --> 01:13:08,560\n',
#   '01:13:08,560 --> 01:13:10,560\n',
#   '01:13:11,650 --> 01:13:19,259\n',
#   '01:13:20,140 --> 01:13:22,559\n',
#   '01:13:23,380 --> 01:13:25,380\n',
#   '01:13:25,480 --> 01:13:26,650\n',
#   '01:13:26,650 --> 01:13:32,129\n',
#   '01:13:33,100 --> 01:13:38,999\n',
#   '01:13:39,700 --> 01:13:41,700\n',
#   '01:13:42,219 --> 01:13:48,899\n',
#   '01:13:50,620 --> 01:13:55,620\n',
#   '01:13:56,920 --> 01:14:00,960\n',
#   '01:14:01,810 --> 01:14:03,200\n',
#   '01:14:04,740 --> 01:14:06,740\n',
#   '01:14:07,350 --> 01:14:10,610\n',
#   '01:14:11,340 --> 01:14:14,389\n',
#   '01:14:15,150 --> 01:14:17,150\n',
#   '01:14:17,520 --> 01:14:21,410\n',
#   '01:14:22,260 --> 01:14:24,800\n',
#   '01:15:05,860 --> 01:15:11,639\n',
#   '01:15:12,760 --> 01:15:20,699\n',
#   '01:15:21,220 --> 01:15:23,220\n',
#   '01:15:23,560 --> 01:15:30,089\n',
#   '01:15:31,000 --> 01:15:34,139\n',
#   '01:15:35,050 --> 01:15:36,520\n',
#   '01:15:36,520 --> 01:15:38,520\n',
#   '01:15:38,800 --> 01:15:40,800\n',
#   '01:15:41,470 --> 01:15:43,030\n',
#   '01:15:47,950 --> 01:15:49,300\n',
#   '01:15:49,300 --> 01:15:51,989\n',
#   '01:15:53,530 --> 01:15:56,489\n',
#   '01:15:57,280 --> 01:16:00,090\n',
#   '01:16:01,000 --> 01:16:03,000\n',
#   '01:16:03,430 --> 01:16:05,430\n',
#   '01:16:05,500 --> 01:16:08,939\n',
#   '01:16:10,210 --> 01:16:12,509\n',
#   '01:16:13,420 --> 01:16:16,319\n',
#   '01:16:16,750 --> 01:16:22,919\n',
#   '01:16:24,250 --> 01:16:29,069\n',
#   '01:16:30,790 --> 01:16:34,319\n',
#   '01:16:35,140 --> 01:16:36,760\n',
#   '01:16:36,760 --> 01:16:39,060\n',
#   '01:16:40,090 --> 01:16:42,270\n',
#   '01:16:42,910 --> 01:16:44,910\n',
#   '01:16:45,580 --> 01:16:50,039\n',
#   '01:16:51,130 --> 01:16:52,630\n',
#   '01:16:52,630 --> 01:16:54,630\n',
#   '01:16:55,330 --> 01:16:57,330\n',
#   '01:16:58,030 --> 01:17:02,280\n',
#   '01:17:03,610 --> 01:17:10,889\n',
#   '01:17:37,469 --> 01:17:41,178\n',
#   '01:17:42,480 --> 01:17:46,310\n',
#   '01:17:47,730 --> 01:17:49,730\n',
#   '01:17:51,179 --> 01:17:56,239\n',
#   '01:17:57,330 --> 01:17:59,419\n',
#   '01:18:00,030 --> 01:18:02,300\n',
#   '01:18:02,850 --> 01:18:04,999\n',
#   '01:18:05,520 --> 01:18:07,290\n',
#   '01:18:13,800 --> 01:18:15,780\n',
#   '01:18:15,780 --> 01:18:20,719\n',
#   '01:18:21,719 --> 01:18:24,198\n',
#   '01:18:44,630 --> 01:18:47,770\n',
#   '01:18:48,469 --> 01:18:52,598\n',
#   '01:18:53,630 --> 01:18:56,380\n',
#   '01:18:57,980 --> 01:19:01,509\n',
#   '01:19:02,389 --> 01:19:04,539\n',
#   '01:19:05,389 --> 01:19:07,130\n',
#   '01:19:07,130 --> 01:19:10,449\n',
#   '01:19:11,090 --> 01:19:13,599\n',
#   '01:19:14,389 --> 01:19:16,280\n',
#   '01:19:16,280 --> 01:19:20,440\n',
#   '01:19:20,989 --> 01:19:26,019\n',
#   '01:19:26,900 --> 01:19:28,900\n',
#   '01:19:50,199 --> 01:19:54,449\n',
#   '01:19:55,119 --> 01:19:57,119\n',
#   '01:19:57,130 --> 01:20:00,359\n',
#   '01:20:01,030 --> 01:20:03,749\n',
#   '01:20:04,659 --> 01:20:06,659\n',
#   '01:20:07,329 --> 01:20:09,329\n',
#   '01:20:10,269 --> 01:20:12,269\n',
#   '01:20:12,909 --> 01:20:15,839\n',
#   '01:20:16,479 --> 01:20:20,099\n',
#   '01:20:20,860 --> 01:20:26,099\n',
#   '01:20:26,860 --> 01:20:29,130\n',
#   '01:20:30,010 --> 01:20:32,010\n']}

# %%
# Convert dictionary to dataframe
speechframe = pd.DataFrame(speechdict)

# Get rid of the empty linebreak column
speechframe = speechframe.drop('linebreak', axis=1)

# Method to clean up the time field. x = the string value currently in the dataframe
def clean(x):
    x = x[0:8]  # Strip away the extraneous parts of the original string
    x = datetime.strptime(x, '%H:%M:%S')  # Convert the string to a datetime object
    x += timedelta(days =43129, hours=2, minutes=10, seconds=14)  # Synchronise it with tweet time
    return x

speechframe['tweettime'] = speechframe['time'].apply(clean)

# %%
writer = pd.ExcelWriter('speechoutput.xlsx')
speechframe.to_excel(writer,'Sheet1')
writer.save()
